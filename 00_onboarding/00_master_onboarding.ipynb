# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ChrisW09/Python-for-AI-Driven-Automation/blob/main/00_onboarding/00_master_onboarding.ipynb)
#
# # 📓 Notebook 0 — Master Onboarding
#
# > **You are here.** This is the *first* notebook of the course. Read it, run its cells, then start the next module.
# > Time budget: ~20 minutes.
#
# ---
#
# # Python for AI-Driven Automation and Business Data Science
#
# You're about to embark on a 47-notebook journey (46 numbered + this onboarding) from `print("Hello")` to **shipping a real AI-powered automation**. This onboarding notebook tells you:
#
# 1. What this course is — and what it is *not*.
# 2. How to study it effectively as a self-learner.
# 3. How the modules fit together.
# 4. Which learning path fits you best.
# 5. What you'll need to install — and how to check it works right now.
# 6. A quick environment sanity check that runs in this cell.
#
# By the end of this notebook you'll have a working Python environment and a clear mental map of where you're going.
#
# > 📓 **Want the full map?** Once you've finished this notebook, open the companion [`00b_course_overview.ipynb`](./00b_course_overview.ipynb) — it has the module-map diagram, per-notebook time budgets (read + run + practice + stretch + bonus), and an interactive estimator that lets you compute the total time for *your* learning path.

# %% [markdown]
# ## ▶️ How to run these notebooks
#
# You have two options:
#
# - **☁️ Google Colab (recommended, zero setup).** Click the **"Open in Colab"** badge at the top of any notebook. **You need a free Google account** — the first time you press **Run**, Colab asks you to sign in (any Gmail account works) so it can give you a free cloud runtime. Without signing in you can *read* a notebook but not *execute* its cells. All required libraries come pre-installed.
# - **💻 Local Jupyter (no Google account needed).** Clone the repo, `pip install -r requirements.txt`, then `jupyter notebook` — or just open the `.ipynb` files in VS Code with the Jupyter extension.
#
# > 🔑 **Bottom line:** to *run* (not just view) the notebooks on Colab, sign in with a free Google account. Prefer not to? Use the local Jupyter / VS Code route instead.

# %% [markdown]
# ## 🧭 The recommended order — a quick spiral
#
# This course builds the skills **bottom-up** (you can't build an AI app before you can write Python), but you don't have to wait until the end to see *why* it matters. The recommended route is a **spiral**: see the destination, build the skills, then build the real thing.
#
# 1. **See it work (5 min).** Run [`00c_see_it_work.ipynb`](./00c_see_it_work.ipynb) — a tiny *offline* demo of AI triage + RAG + a KPI snapshot, so the Python you learn next has an obvious destination. Optionally skim **NB 43 — Digital Transformation** (no coding) for the business *why*, and **NB 21 — LLM Fundamentals** for *what an LLM actually is*.
# 2. **Build the skills, in order (Modules 1 → 6).** Python → data → real-world I/O → machine learning → industry ML applications → AI engineering. Set up your professional toolchain **early**: do **NB 45 (Git, GitHub, Copilot)** right after the Python basics — that workflow pays off in every later notebook.
# 3. **Build the real thing (Modules 7 → 12).** Hands-on POCs (**Module 7** — a 3-tier app, a RAG-over-PDF, an agent), then agents, tools & the Model Context Protocol (**Module 8**, NB 31–34), the optional NLP / DeepTab tracks (**Modules 9–10**), and finally package and ship it with production patterns and CI/CD (**Modules 11–12**).
# 4. **Synthesise.** **Module 13** — two end-to-end capstones you can talk through in an interview — then **Module 14 (Business AI)** for the judgement to deploy them inside an organisation (architecture, governance, POC → MVP → Production).
#
# > 💡 **New to programming?** Following the modules in numeric order *is* the spiral — step 1 (the demo) is simply pulled to the front. The orientation notebooks above are optional accelerants, not detours.

# %% [markdown]
# ## 1. The course in one paragraph
#
# Modern data work isn't *just* spreadsheets, *just* dashboards, or *just* training models. It's a blend: programming with Python, wrangling and visualising data, training small ML models, calling LLMs from your code, and packaging the result so a scheduler runs it overnight.
#
# This course teaches *that combination* — through hands-on, runnable notebooks anchored in realistic AI-and-business scenarios.

# %% [markdown]
# ## 2. Where the course sits
#
# ```
#                  ┌──────────────────────────┐
#                  │     Python fluency        │
#                  │  (NB 1–6)                 │
#                  └────────────┬─────────────┘
#                               │
#             ┌─────────────────┴─────────────────┐
#             ▼                                    ▼
#   ┌────────────────────┐              ┌────────────────────┐
#   │   Business Data    │              │        AI          │
#   │      Science       │ ◄─ overlap ─►│    Engineering      │
#   │  (NB 7–13, ML      │  this course │  (NB 21–26, POCs    │
#   │   14–16, industry  │              │   26–30, agents     │
#   │   17–20)           │              │   31–34)            │
#   └─────────┬──────────┘              └──────────┬─────────┘
#             │                                    │
#             └─────────────────┬─────────────────┘
#                               ▼
#                  ┌───────────────────────────┐
#                  │  Ship it: Production       │
#                  │  (39–40) + CI/CD  →        │
#                  │  Capstones (41–42)  →      │
#                  │  Business AI (43–46)       │
#                  └───────────────────────────┘
# ```
#
# Other courses pick *one* circle. This one teaches the overlap — because that's where modern data jobs live — then takes you all the way to shipping and the business judgement to deploy.

# %% [markdown]
# ## 3. How to study a notebook — the 5-step loop
#
# Apply this to *every* notebook in the course:
#
# | Step | What to do | Why it works |
# |---|---|---|
# | 1️⃣ Read | Read the prose *before* looking at the code. | Code without intuition is fragile. |
# | 2️⃣ Run | Execute every code cell as you go. Watch the output. | Reading isn't fluency; running is. |
# | 3️⃣ Try | Try each exercise yourself *before* clicking the solution. | 5 minutes of struggle beats 5 hours of passive reading. |
# | 4️⃣ Tweak | Change one number, re-run, see what happens. | The fastest path to real understanding. |
# | 5️⃣ Predict | Before re-running, predict the new output. | Trains the mental model the course is trying to build. |
#
# You will not need to memorise anything. The notebooks are full of cheat-sheets you can come back to.

# %% [markdown]
# ## 4. The modules at a glance
#
# | # | Module | Notebooks | What you'll build |
# |---|---|---|---|
# | 0 | **Onboarding** | this NB + 2 more | A working environment and a clear map |
# | 1 | **Foundations** | NB 1–6 | Confidence with Python syntax — types, control, data structures, functions |
# | 2 | **Data Science** | NB 7–11 | pandas, NumPy, seaborn/matplotlib, statistics, time series & forecasting |
# | 3 | **Real-world I/O** | NB 12–13 | Live HTTP calls, SQL queries, Pydantic-validated data |
# | 4 | **Machine Learning** | NB 14–16 | scikit-learn workflow + proper evaluation + feature engineering |
# | 5 | **Industry Applications** | NB 17–20 | Churn + CLV, fraud detection, segmentation + recommenders, forecasting + maintenance |
# | 6 | **AI Engineering** | NB 21–26 | LLM fundamentals, prompts, RAG, agents, document processing, evaluation |
# | 7 | **Building AI POCs (hands-on)** | NB 27–30 | Hands-on LLM prototypes — Copilot setup, RAG deep dive, agentic AI |
# | 8 | **Agents, Tools & MCP** | NB 31–34 | Hardened production-grade tools, an MCP server & client, a multi-agent pipeline |
# | 9 | **NLP — Text Analytics** *(optional)* | NB 35–37 | Topic modeling (BERTopic, STREAM) + sentiment analysis |
# | 10 | **DeepTab** *(optional)* | NB 38 | Deep learning for tabular data behind a scikit-learn API |
# | 11 | **Production** | NB 39–40 | Packaging, scheduling, config & secrets management |
# | 12 | **CI/CD & Deployment** | mini-book | Docker, Compose, GitHub Actions, registries, reverse proxies, HTTPS |
# | 13 | **Capstones** | NB 41–42 | Two end-to-end projects you can ship and talk through in an interview |
# | 14 | **Business AI in Practice** | NB 43–46 | The judgement to deploy AI inside an organisation — architecture, governance, POC → MVP → Production |
#
#
#
# Each module folder has its own `README.md` with goals, prerequisites, and an overview diagram.

# %% [markdown]
# ## 5. Pick a learning path
#
# Not every reader needs every notebook. Match yourself to one of these (hours match the per-notebook estimator in [`00b_course_overview.ipynb`](./00b_course_overview.ipynb)):
#
# ```
# Complete beginner        :  00c demo → every module, in order               ~115h
# Analyst (knows SQL/Excel):  skim Module 1; engage Modules 2–5 + a capstone   ~43h
# Developer (knows Python) :  skim Module 1; engage Modules 2–13               ~55h
# ML practitioner          :  skip Modules 1–4; engage Modules 5–8 + 11        ~34h
# Manager / curious        :  this onboarding + the two capstones (read-mode)  ~10h
# ```
#
# > 💡 **You can change paths.** Many learners start with one and switch to "complete beginner" once they realise how much they miss. That's fine. For an exact, per-notebook estimate of *your* path, use the interactive estimator in [`00b_course_overview.ipynb`](./00b_course_overview.ipynb).

# %% [markdown]
# ## 6. Environment check — let's make sure everything works
#
# Run the cell below. It will:
#
# - Confirm your Python version (3.10+ is required, 3.11+ is recommended).
# - Confirm the core libraries are importable.
# - Print the versions so a forum post about a bug has the right info.
#
# If anything fails, scroll down to the **troubleshooting** section.

# %%
import sys, importlib, platform

REQUIRED = {
    "numpy":         "≥ 1.24",
    "pandas":        "≥ 2.0",
    "matplotlib":    "≥ 3.7",
    "seaborn":       "≥ 0.13",
    "sklearn":       "≥ 1.3   (package name: scikit-learn)",
}
OPTIONAL = {
    "requests":      "needed for Notebook 12 (HTTP)",
    "statsmodels":   "needed for Notebook 11 (time series)",
    "pytest":        "needed for Notebook 39 (testing)",
}

def check(pkg, why):
    try:
        m = importlib.import_module(pkg)
        v = getattr(m, "__version__", "?")
        return f"  ✓ {pkg:<14} {v:<8}  ({why})"
    except ImportError:
        return f"  ✗ {pkg:<14} MISSING   ({why})"

print(f"Python    : {sys.version.split()[0]}  ({platform.platform()})")
print(f"Executable: {sys.executable}\n")
print("Required:")
for p, w in REQUIRED.items():
    print(check(p, w))
print("\nOptional (install when you reach those modules):")
for p, w in OPTIONAL.items():
    print(check(p, w))

# %% [markdown]
# ### If something is missing
#
# In the very same notebook, run **one** of:
#
# ```python
# # Quick fix from a notebook cell:
# !pip install numpy pandas matplotlib seaborn scikit-learn
#
# # For the full optional set (you'll need them eventually):
# !pip install -r requirements.txt
# ```
#
# > ⚠️ **If you're on Colab** all the required libraries are pre-installed — you should see ✓ next to every required package above. Optional libraries you'll install on demand inside each notebook. (Remember: running cells on Colab requires being **signed in with a free Google account** — see *"How to run these notebooks"* near the top.)

# %% [markdown]
# ## 7. A tiny self-test — can you run Python *right now*?

# %%
# If this cell prints "✅ Setup looks good!" — you're ready to start.
import math

x = 42
greeting = f"Hello, learner!  √x = {math.sqrt(x):.3f}"
print(greeting)
assert greeting.startswith("Hello"), "Something's off"
print("\n✅ Setup looks good!  Next: run 00c_see_it_work.ipynb (a 5-min demo), then Section 11 picks your starting notebook.")

# %% [markdown]
# ## 8. A note on style — what makes these notebooks different
#
# Across all 46 numbered notebooks you'll see the same visual conventions:
#
# | Marker | Meaning |
# |---|---|
# | 💡 **Tip** | A small "stop and notice this" callout. |
# | 🎯 **Intuition** | The mental model behind the syntax. |
# | ⚠️ **Pitfall** | A bug or anti-pattern that will bite you if you're not warned. |
# | 🧪 **Exercises** | Hands-on tasks. Try them before peeking at the solution. |
# | 🎁 **Bonus mini-project** | One larger applied task per notebook. |
# | 🐞 **Debug me** | A cell that *intentionally* contains a bug for you to find. It's not broken — it's a puzzle. |
# | 🧠 **Mental model** | A plain-language explanation of *what Python is actually doing under the hood*. |
# | ⭐ / ⭐⭐ / ⭐⭐⭐ **Difficulty** | Star count after the exercise title indicates difficulty: ⭐ warmup, ⭐⭐ standard, ⭐⭐⭐ stretch. Practice exercises range from ⭐ to ⭐⭐; Stretch exercises are ⭐⭐⭐. |
# | 🔭 **Forward-reference** | A short callout telling you that the next bit of code uses something we haven't taught yet — and pointing to where it *will* be properly introduced. |
# | 🚀 **Next step** | Always points to the next notebook in your path. |
#
# The course gets more enjoyable once you internalise the markers — they're road signs, not decoration.

# %% [markdown]
# ## 9. What this course is *not*
#
# So you're not surprised later:
#
# - ❌ **Not a deep-learning course.** No PyTorch in the main track, and no training transformers from scratch — the main track teaches *using* pre-trained models, which is what most working AI applications need today. (If you do want PyTorch, the optional Module 4 appendices `A1`–`A3` cover it.)
# - ❌ **Not a statistics course.** It introduces just enough stats to do its job (NB 10). For rigour, follow up with a dedicated stats book.
# - ❌ **Not a cloud course.** Notebook 40 shows the *patterns* of scheduling (cron, systemd, GitHub Actions, Prefect) but doesn't commit to AWS/GCP/Azure.
# - ❌ **Not a vendor showcase.** No "and here's how Snowflake/Databricks/X does it". The course teaches *fundamentals* that travel.
#
# These are conscious trade-offs — the course is deep where it counts and stays out of vendor wars elsewhere.

# %% [markdown]
# ## 10. Troubleshooting — when something doesn't work
#
# | Symptom | Likely cause | Fix |
# |---|---|---|
# | `ModuleNotFoundError: No module named X` | Library not installed in this kernel | `!pip install X` *in this notebook* (then restart kernel) |
# | Cell runs forever | Something hit a network timeout | Edit the cell, add `timeout=8`, restart kernel, re-run |
# | `IndentationError` | Mixed tabs and spaces | Pick "Convert indentation to spaces" in your editor |
# | Different output from the solution | Different package version | Check `pip show pandas` etc.; usually harmless |
# | Notebook 12 fails to fetch data | No internet in your sandbox | The notebook has a *recorded* fallback — re-run, check the warning |
#
# > 💡 **When you're stuck for more than 15 minutes**, copy the full error traceback into a search engine before doing anything else. 95% of beginner errors have been documented.

# %% [markdown]
# ## 11. Now → which file do you open next?
#
# **Everyone — 5 minutes first:** run [`00c_see_it_work.ipynb`](./00c_see_it_work.ipynb) to see what you'll build.
#
# Then pick the option that matches your path from Section 5:
#
# - 👶 **Complete beginner** → `01_foundations/01_python_basics.ipynb` — then do **NB 45 (Git + Copilot)** right after Module 1, and follow the modules in numeric order all the way through the capstones (**Module 13**) and Business AI (**Module 14**).
# - 📊 **Analyst** → `01_foundations/01_python_basics.ipynb` (skim through NB 1–6, then full engagement from NB 7 — data science, ML, and industry applications)
# - 💻 **Developer** → `02_data_science/07_pandas_fundamentals.ipynb` (skim Module 1 first if anything there feels unfamiliar)
# - 🤖 **ML practitioner** → `05_industry_applications/17_churn_clv_retention.ipynb` (applied ML), or jump straight to the LLM track at `06_ai_engineering/22_ai_workflows.ipynb`
# - 🧭 **Curious** → `13_capstones/41_capstone_analytics.ipynb` (read it like a story)
#
# > 🎓 You can always come back to this notebook to re-check your environment or pick a different path.
#
# Good luck, and have fun.
