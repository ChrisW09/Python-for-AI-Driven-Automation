# %% [markdown]
# # 📓 Notebook 00 — Master Onboarding
#
# > **You are here.** This is the *first* notebook of the course. Read it, run its cells, then start the next module.
# > Time budget: ~20 minutes.
#
# ---
#
# # Python for AI-Driven Automation and Business Data Science
#
# You're about to embark on a 35-notebook journey (34 numbered + this onboarding) from `print("Hello")` to **shipping a real AI-powered automation**. This onboarding notebook tells you:
#
# 1. What this course is — and what it is *not*.
# 2. How to study it effectively as a self-learner.
# 3. How the modules fit together.
# 4. Which learning path fits you best.
# 5. What you'll need to install — and how to check it works right now.
# 6. A quick environment sanity check that runs in this cell.
#
# By the end of this notebook you'll have a working Python environment and a clear mental map of where you're going.
#
# > 📓 **Want the full map?** Once you've finished this notebook, open the companion [`00b_course_overview.ipynb`](./00b_course_overview.ipynb) — it has the module-map diagram, per-notebook time budgets (read + run + practice + stretch + bonus), and an interactive estimator that lets you compute the total time for *your* learning path.

# %% [markdown]
# ## 1. The course in one paragraph
#
# Modern data work isn't *just* spreadsheets, *just* dashboards, or *just* training models. It's a blend: programming with Python, wrangling and visualising data, training small ML models, calling LLMs from your code, and packaging the result so a scheduler runs it overnight.
#
# This course teaches *that combination* — through hands-on, runnable notebooks anchored in realistic AI-and-business scenarios.

# %% [markdown]
# ## 2. Where the course sits
#
# ```
#                  ┌────────────────────┐
#                  │   Python fluency   │
#                  │   (NB 1–6, 23–24)  │
#                  └──────────┬─────────┘
#                             │
#         ┌───────────────────┼───────────────────┐
#         ▼                                       ▼
#   ┌──────────┐                           ┌────────────┐
#   │ Business │     ◄ — overlap — ►       │     AI     │
#   │   Data   │  ◄ ─ this course ─ ►      │ Engineering│
#   │ Science  │                            │            │
#   │ (NB 7-8, 10-17)│                            │ (NB 18-22) │
#   └──────────┘                           └────────────┘
#         │                                       │
#         └──────────────────┬────────────────────┘
#                            ▼
#                   ┌─────────────────┐
#                   │   Capstones     │
#                   │   (NB 26–27)    │
#                   └─────────────────┘
# ```
#
# Other courses pick *one* circle. This one teaches the overlap — because that's where modern data jobs live.

# %% [markdown]
# ## 3. How to study a notebook — the 5-step loop
#
# Apply this to *every* notebook in the course:
#
# | Step | What to do | Why it works |
# |---|---|---|
# | 1️⃣ Read | Read the prose *before* looking at the code. | Code without intuition is fragile. |
# | 2️⃣ Run | Execute every code cell as you go. Watch the output. | Reading isn't fluency; running is. |
# | 3️⃣ Try | Try each exercise yourself *before* clicking the solution. | 5 minutes of struggle beats 5 hours of passive reading. |
# | 4️⃣ Tweak | Change one number, re-run, see what happens. | The fastest path to real understanding. |
# | 5️⃣ Predict | Before re-running, predict the new output. | Trains the mental model the course is trying to build. |
#
# You will not need to memorise anything. The notebooks are full of cheat-sheets you can come back to.

# %% [markdown]
# ## 4. The modules at a glance
#
# | # | Module | Notebooks | What you'll build |
# |---|---|---|---|
# | 0 | **Onboarding** | this NB + 2 more | A working environment and a clear map |
# | 1 | **Foundations** | NB 1–6 | Confidence with Python syntax — types, control, data structures, functions |
# | 2 | **Real-world I/O** | NB 7–8 | Live HTTP calls, SQL queries, Pydantic-validated data |
# | 3 | **Data Science** | NB 10–14 | pandas, NumPy, matplotlib, statistics, time series & forecasting |
# | 4 | **Machine Learning** | NB 15–17 | scikit-learn workflow + proper evaluation + feature engineering |
# | 5 | **AI Engineering** | NB 18–22 | LLM prompts, RAG, agents, document processing, evaluation |
# | 6 | **Production** | NB 23–24 | Packaging, scheduling, config & secrets management |
# | 7 | **Capstones** | NB 26–27 | Two end-to-end projects you can ship and talk through in an interview |
# | 8 | **Business AI in Practice** | NB 28–31 | The judgement to deploy AI inside an organisation — architecture, governance, POC → MVP → Production |
# | 9 | **Building AI POCs (hands-on)** | NB 32–36 | Hands-on LLM prototypes — Transformer theory, Copilot, RAG, agentic AI |
#
# > 💡 **About the numbering gaps.** NB 09 and 25 are intentionally absent — Pydantic validation was folded into NB 8 and config & secrets into NB 23. NB 6 *was* the documented gap ("extra Python practice"); it is now filled with **Classes & OOP**.
#
#
# Each module folder has its own `README.md` with goals, prerequisites, and an overview diagram.

# %% [markdown]
# ## 5. Pick a learning path
#
# Not every reader needs every notebook. Match yourself to one of these:
#
# ```
# Complete beginner       :  go through every module in order              ~35h
# Analyst (knows SQL/Excel):  skim Module 1, fully engage Modules 2–4, 7   ~20h
# Developer (knows Python) :  skim Modules 1; engage Modules 2–7           ~28h
# ML practitioner          :  skim Module 4; engage Modules 5–7            ~15h
# Manager / curious       :  read only this onboarding + Module 7         ~8h
# ```
#
# > 💡 **You can change paths.** Many learners start with one and switch to "complete beginner" once they realise how much they miss. That's fine.

# %% [markdown]
# ## 6. Environment check — let's make sure everything works
#
# Run the cell below. It will:
#
# - Confirm your Python version (3.10+ is required, 3.11+ is recommended).
# - Confirm the core libraries are importable.
# - Print the versions so a forum post about a bug has the right info.
#
# If anything fails, scroll down to the **troubleshooting** section.

# %%
import sys, importlib, platform

REQUIRED = {
    "numpy":         "≥ 1.24",
    "pandas":        "≥ 2.0",
    "matplotlib":    "≥ 3.7",
    "sklearn":       "≥ 1.3   (package name: scikit-learn)",
}
OPTIONAL = {
    "requests":      "needed for Notebook 7 (HTTP)",
    "statsmodels":   "needed for Notebook 14 (time series)",
    "pytest":        "needed for Notebook 23 (testing)",
}

def check(pkg, why):
    try:
        m = importlib.import_module(pkg)
        v = getattr(m, "__version__", "?")
        return f"  ✓ {pkg:<14} {v:<8}  ({why})"
    except ImportError:
        return f"  ✗ {pkg:<14} MISSING   ({why})"

print(f"Python    : {sys.version.split()[0]}  ({platform.platform()})")
print(f"Executable: {sys.executable}\n")
print("Required:")
for p, w in REQUIRED.items():
    print(check(p, w))
print("\nOptional (install when you reach those modules):")
for p, w in OPTIONAL.items():
    print(check(p, w))

# %% [markdown]
# ### If something is missing
#
# In the very same notebook, run **one** of:
#
# ```python
# # Quick fix from a notebook cell:
# !pip install numpy pandas matplotlib scikit-learn
#
# # For the full optional set (you'll need them eventually):
# !pip install -r requirements.txt
# ```
#
# > ⚠️ **If you're on Colab** all the required libraries are pre-installed — you should see ✓ next to every required package above. Optional libraries you'll install on demand inside each notebook.

# %% [markdown]
# ## 7. A tiny self-test — can you run Python *right now*?

# %%
# If this cell prints "✅ Setup looks good!" — you're ready to start.
import math

x = 42
greeting = f"Hello, learner!  √x = {math.sqrt(x):.3f}"
print(greeting)
assert greeting.startswith("Hello"), "Something's off"
print("\n✅ Setup looks good!  Open Module 1 next: 01_foundations/01_python_basics.ipynb")

# %% [markdown]
# ## 8. A note on style — what makes these notebooks different
#
# Across all 35 notebooks you'll see the same visual conventions:
#
# | Marker | Meaning |
# |---|---|
# | 💡 **Tip** | A small "stop and notice this" callout. |
# | 🎯 **Intuition** | The mental model behind the syntax. |
# | ⚠️ **Pitfall** | A bug or anti-pattern that will bite you if you're not warned. |
# | 🧪 **Exercises** | Hands-on tasks. Try them before peeking at the solution. |
# | 🎁 **Bonus mini-project** | One larger applied task per notebook. |
# | 🐞 **Debug me** | A cell that *intentionally* contains a bug for you to find. It's not broken — it's a puzzle. |
# | 🧠 **Mental model** | A plain-language explanation of *what Python is actually doing under the hood*. |
# | ⭐ / ⭐⭐ / ⭐⭐⭐ **Difficulty** | Star count after the exercise title indicates difficulty: ⭐ warmup, ⭐⭐ standard, ⭐⭐⭐ stretch. Practice exercises range from ⭐ to ⭐⭐; Stretch exercises are ⭐⭐⭐. |
# | 🔭 **Forward-reference** | A short callout telling you that the next bit of code uses something we haven't taught yet — and pointing to where it *will* be properly introduced. |
# | 🚀 **Next step** | Always points to the next notebook in your path. |
#
# The course gets more enjoyable once you internalise the markers — they're road signs, not decoration.

# %% [markdown]
# ## 9. What this course is *not*
#
# So you're not surprised later:
#
# - ❌ **Not a deep-learning course.** No PyTorch, no training transformers from scratch. The course teaches *using* pre-trained models — which is what most working AI applications need today.
# - ❌ **Not a statistics course.** It introduces just enough stats to do its job (NB 13). For rigour, follow up with a dedicated stats book.
# - ❌ **Not a cloud course.** Notebook 24 shows the *patterns* of scheduling (cron, systemd, GitHub Actions, Prefect) but doesn't commit to AWS/GCP/Azure.
# - ❌ **Not a vendor showcase.** No "and here's how Snowflake/Databricks/X does it". The course teaches *fundamentals* that travel.
#
# These are conscious trade-offs — the course is deep where it counts and stays out of vendor wars elsewhere.

# %% [markdown]
# ## 10. Troubleshooting — when something doesn't work
#
# | Symptom | Likely cause | Fix |
# |---|---|---|
# | `ModuleNotFoundError: No module named X` | Library not installed in this kernel | `!pip install X` *in this notebook* (then restart kernel) |
# | Cell runs forever | Something hit a network timeout | Edit the cell, add `timeout=8`, restart kernel, re-run |
# | `IndentationError` | Mixed tabs and spaces | Pick "Convert indentation to spaces" in your editor |
# | Different output from the solution | Different package version | Check `pip show pandas` etc.; usually harmless |
# | Notebook 7 fails to fetch data | No internet in your sandbox | The notebook has a *recorded* fallback — re-run, check the warning |
#
# > 💡 **When you're stuck for more than 15 minutes**, copy the full error traceback into a search engine before doing anything else. 95% of beginner errors have been documented.

# %% [markdown]
# ## 11. Now → which file do you open next?
#
# Pick the option that matches your path from Section 5:
#
# - 👶 **Complete beginner** → `01_foundations/01_python_basics.ipynb`
# - 📊 **Analyst** → `01_foundations/01_python_basics.ipynb` (skim through NB 1–6, then full engagement from NB 7)
# - 💻 **Developer** → `02_real_world_io/07_apis_and_http.ipynb` (skim Module 1 first if any cell in this notebook felt unfamiliar)
# - 🤖 **ML practitioner** → `05_ai_engineering/18_ai_workflows.ipynb`
# - 🧭 **Curious** → `07_capstones/26_capstone_analytics.ipynb` (read it like a story)
#
# > 🎓 You can always come back to this notebook to re-check your environment or pick a different path.
#
# Good luck, and have fun.
