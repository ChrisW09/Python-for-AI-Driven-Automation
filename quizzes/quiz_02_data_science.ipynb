# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ChrisW09/python-ai-business-data-science/blob/main/quizzes/quiz_02_data_science.ipynb)
#
# # 🧪 Module 2 Quiz — Data Science
#
# Five recall questions to check what stuck after Module 2.
#
# - **Format:** multiple choice; each question has one correct answer.
# - **Time:** ~12 minutes.
# - **How to use:** read the question, decide which answer you think is correct, *then* click the **Answer + reasoning** block. Don't peek.
#
# > 💡 **Fast-track learners:** this quiz includes NumPy and statistics from the full course — material the fast track skips (it keeps pandas only). Treat those questions as optional unless you've done Module 3.
#
# ---

# %% [markdown]
# ### Q1 — Groupby semantics
#
# What does `df.groupby("region")["revenue"].sum()` return?
#
# - **A.** A Series indexed by region, values are summed revenues
# - **B.** A DataFrame with columns `region` and `revenue`
# - **C.** A list of revenue sums
# - **D.** A single number
#
# <details>
# <summary>💡 <b>Answer + reasoning</b></summary>
#
# **Correct answer: A.**
#
# `groupby(key)[col].agg(...)` returns a Series whose index is the group key and whose values are the aggregated quantity. To get a DataFrame instead, append `.reset_index()` or use double brackets: `df.groupby("region")[["revenue"]].sum()`.
# </details>

# %% [markdown]
# ### Q2 — Missing data
#
# Which of these reliably removes rows where `df["score"]` is missing?
#
# - **A.** `df[df["score"] != None]`
# - **B.** `df[df["score"].notna()]`
# - **C.** `df[df["score"] != np.nan]`
# - **D.** `df[df["score"] != ""]`
#
# <details>
# <summary>💡 <b>Answer + reasoning</b></summary>
#
# **Correct answer: B.**
#
# Comparing to `np.nan` is **always False** (`np.nan != np.nan`), so option C silently removes nothing. `None` comparisons are similarly broken on float columns. Always use `.notna()` / `.isna()` / `pd.notna(x)`.
# </details>

# %% [markdown]
# ### Q3 — Broadcasting in NumPy
#
# If `a` has shape `(3, 1)` and `b` has shape `(1, 4)`, what is the shape of `a + b`?
#
# - **A.** `(3,)`
# - **B.** `(4,)`
# - **C.** `(3, 4)`
# - **D.** Error — shapes don't match
#
# <details>
# <summary>💡 <b>Answer + reasoning</b></summary>
#
# **Correct answer: C.**
#
# NumPy broadcasting expands a `(3, 1)` array and a `(1, 4)` array to a common `(3, 4)` shape — the `1` dimensions are stretched to match the other operand. This is how outer-product-style computations get written in one line.
# </details>

# %% [markdown]
# ### Q4 — Matplotlib pattern
#
# Which is the **recommended** way to make a figure with one subplot?
#
# - **A.** `plt.plot(x, y); plt.show()`
# - **B.** `fig, ax = plt.subplots(); ax.plot(x, y); plt.show()`
# - **C.** `plot(x, y)`
# - **D.** `matplotlib.draw(x, y)`
#
# <details>
# <summary>💡 <b>Answer + reasoning</b></summary>
#
# **Correct answer: B.**
#
# The object-oriented API (`fig, ax = plt.subplots()`) is preferred because: (1) it works the same when you have many subplots; (2) it doesn't depend on the implicit "current figure" state which causes hard-to-debug ordering bugs. The pyplot state-machine version (A) is fine for one-off scripts but breaks down quickly.
# </details>

# %% [markdown]
# ### Q5 — Confidence intervals
#
# You compute a 95% confidence interval for the mean and get `[1.2, 1.8]`. What does this mean?
#
# - **A.** 95% of values are between 1.2 and 1.8
# - **B.** There is a 95% probability the true mean is between 1.2 and 1.8
# - **C.** If we re-sampled many times, 95% of the resulting CIs would contain the true mean
# - **D.** 95% of our sample is between 1.2 and 1.8
#
# <details>
# <summary>💡 <b>Answer + reasoning</b></summary>
#
# **Correct answer: C.**
#
# This is the textbook subtle distinction. A 95% CI is a statement about the **procedure**: of all the CIs you could compute from independent samples, 95% of them would contain the true mean. The naïve "there's a 95% chance" reading is Bayesian — strictly speaking, frequentist CIs are not probability statements about the parameter.
# </details>

# %% [markdown]
# ---
#
# ## How did you do?
#
# - **5/5** — you've got it. Move on.
# - **3-4/5** — solid. Re-read any notebook section you were unsure about, then move on.
# - **0-2/5** — re-do the module's notebooks before continuing. The next module builds on this one.
#
# 🚀 **Next:** [`../03_real_world_io/12_apis_and_http.ipynb`](../03_real_world_io/12_apis_and_http.ipynb) — Module 3 — Real-world I/O.
